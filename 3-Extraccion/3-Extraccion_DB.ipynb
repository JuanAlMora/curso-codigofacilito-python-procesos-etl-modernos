# %% [markdown]
# # Extracción de datos desde bases de datos

# %% [markdown]
# ## Conexión a bases de datos relacionales con ODBC y SQLAlchemy

# %% [markdown]
# #### Tipos de módulos de conexión
# Para desarrollar un proyecto en Python en el que se quiera implementar el uso "Bases de Datos SQL", se tienen distintos módulos que pueden ser útiles, por ejemplo "PYODBC" que es uno de ellos.
#
# **ODBC:**
#
# Open DataBase Connectivity (ODBC) es un estándar de acceso a las bases de datos desarrollado por SQL Access Group (SAG) en 1992. El objetivo de ODBC es hacer posible el acceder a cualquier dato desde cualquier aplicación, sin importar qué sistema de gestión de bases de datos (DBMS) almacené los datos.
#
# **PYODBC:**
#
# Pyodbc es un módulo de Python de código abierto que simplifica el acceso a las bases de datos "ODBC" desde Python, implementando el uso de la DB API 2.0 de una forma conveniente para Python. Pyodbc también es considerado como un controlador SQL para Python.

# %% [markdown]
# ### Conexión a bases de datos SQL Server utilizando cursor

# %% [markdown]
# #### Configuracion de SQL Server
#
# So just open the access to your 127.0.0.1:1433 in the SQL server Configuration Manager.
#
# Steps:
#
# - Start -> All Programs -> SQL Server Configuration Manager
# - SQL Server Network Configuration -> Protocols for MSSQLSERVER -> TCP/IP (Enable it)
# - TCP/IP -> Properties -> IP Addresses. Find 127.0.0.1 and change the "Enabled" to "Yes". You can do it for all the IPs if you want.

# %%
! conda install pymssql -y
# Out:
# Channels:
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - package pymssql-2.1.4-py27h0c8e037_0 requires python >=2.7,<2.8.0a0, but none of the providers can be installed
#
# Could not solve for environment specs
# The following packages are incompatible
# ├─ pin-1 is installable and it requires
# │  └─ python 3.12.* , which can be installed;
# └─ pymssql is not installable because there are no viable options
#    ├─ pymssql 2.1.4 would require
#    │  └─ python >=2.7,<2.8.0a0 , which conflicts with any installable versions previously reported;
#    ├─ pymssql [2.1.4|2.2.5] would require
#    │  └─ python >=3.10,<3.11.0a0 , which conflicts with any installable versions previously reported;
#    ├─ pymssql 2.1.4 would require
#    │  └─ python >=3.5,<3.6.0a0 , which conflicts with any installable versions previously reported;
#    ├─ pymssql [2.1.4|2.1.5] would require
#    │  └─ python >=3.6,<3.7.0a0 , which conflicts with any installable versions previously reported;
#    ├─ pymssql [2.1.4|2.1.5|2.2.3|2.2.5] would require
#    │  └─ python >=3.7,<3.8.0a0 , which conflicts with any installable versions previously reported;
#    ├─ pymssql [2.1.4|2.1.5|2.2.3|2.2.5] would require
#    │  └─ python >=3.8,<3.9.0a0 , which conflicts with any installable versions previously reported;
#    ├─ pymssql [2.1.4|2.2.3|2.2.5] would require
#    │  └─ python >=3.9,<3.10.0a0 , which conflicts with any installable versions previously reported;
#    └─ pymssql [2.2.3|2.2.5] would require
#       └─ python >=3.11,<3.12.0a0 , which conflicts with any installable versions previously reported.
#
# Pins seem to be involved in the conflict. Currently pinned specs:
#  - python 3.12.* (labeled as 'pin-1')
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed

# %%
import pymssql

conn = pymssql.connect(
    server='DSANDOVALFLAVIO', 
    database='cf_etl'
)

# %%
# Crear el cursor y ver las tablas de la base de datos
cursor = conn.cursor()
cursor.execute('SELECT * FROM information_schema.tables')
cursor.fetchall()
# Out:
# [('cf_etl', 'dbo', 'dataset', 'BASE TABLE')]

# %%
query = 'SELECT top 3 * FROM cf_etl.dbo.dataset'
cursor.execute(query)
data = cursor.fetchall()
data
# Out:
# [('12/24/2023',
#   'CursosDeProgramacion',
#   'Oeste',
#   '26148',
#   '133468',
#   '21979',
#   '606'),
#  ('11/11/2023',
#   'AprendeCSharpFacil',
#   'Norte',
#   '34586',
#   '340290',
#   '49146',
#   '495'),
#  ('5/24/2024',
#   'CodigoFacilitoEnEspanol',
#   'Norte',
#   '20337',
#   '343710',
#   '32831',
#   '1655')]

# %% [markdown]
# ### Conexión a bases de datos SQL Server utilizando ODBC y SQLAlchemy

# %%
! conda install pyodbc -y

# %%
! conda install sqlalchemy -y
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\flavi\anaconda3\envs\tch_cf_etl_env
#
#   added / updated specs:
#     - sqlalchemy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     greenlet-3.0.1             |  py312hd77b12b_0         219 KB
#     sqlalchemy-2.0.30          |  py312h827c3e9_0         3.8 MB
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   greenlet           pkgs/main/win-64::greenlet-3.0.1-py312hd77b12b_0
#   sqlalchemy         pkgs/main/win-64::sqlalchemy-2.0.30-py312h827c3e9_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# Drivers Disponibles

# %%
import pyodbc

pyodbc.drivers()
# Out:
# ['SQL Server',
#  'PostgreSQL ODBC Driver(ANSI)',
#  'PostgreSQL ODBC Driver(UNICODE)',
#  'ODBC Driver 17 for SQL Server']

# %%
from sqlalchemy import create_engine

driver = 'ODBC Driver 17 for SQL Server'
server = 'DSANDOVALFLAVIO'
database = 'cf_etl'

engine = create_engine(f'mssql+pyodbc://{server}/{database}?driver={driver}')

# Testear la conexión
try:
    conn = engine.connect()
    print('Conexión exitosa')
except Exception as e:
    print(f'Error en la conexión: {e}')
# Out:
# Conexión exitosa

# %%
import pandas as pd

df_table = pd.read_sql_table('dataset', engine)
df_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Fecha                  1000 non-null   object
#  1   Nombre de la CampaÃ±a  1000 non-null   object
#  2   Region                 1000 non-null   object
#  3   Clicks                 1000 non-null   object
#  4   Impresiones            1000 non-null   object
#  5   Views                  1000 non-null   object
#  6   Costo                  1000 non-null   object
# dtypes: object(7)
# memory usage: 54.8+ KB

# %% [markdown]
# ### Ejecución de consultas SQL para extraer datos específicos

# %%
query = """
SELECT * 
FROM cf_etl.dbo.dataset 
WHERE sCampaign = 'CursosDeProgramacion'
"""

df = pd.read_sql(
    sql=query, 
    con=engine,
    
    )
df
# Out:
#          Fecha             sCampaign Region Clicks Impresiones  Views Costo
# 0   12/24/2023  CursosDeProgramacion  Oeste  26148      133468  21979   606
# 1    3/12/2024  CursosDeProgramacion  Oeste  32254      206296   6448   726
# 2    3/20/2024  CursosDeProgramacion  Norte   7761      178949  47475   862
# 3   10/22/2023  CursosDeProgramacion   Este  42967      356762   7496  1722
# 4    4/22/2024  CursosDeProgramacion  Norte  13362      157531  47034   517
# ..         ...                   ...    ...    ...         ...    ...   ...
# 92    4/1/2024  CursosDeProgramacion  Oeste  29805      381302  19833  1152
# 93   5/12/2024  CursosDeProgramacion    Sur  49996       79199  38665  1603
# 94    5/7/2024  CursosDeProgramacion   Este  22068      435276  34668   577
# 95  10/31/2023  CursosDeProgramacion   Este  31943      248545  21555   882
# 96   1/28/2024  CursosDeProgramacion    Sur  12424      178723  17621  1086
#
# [97 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha        97 non-null     object
#  1   sCampaign    97 non-null     object
#  2   Region       97 non-null     object
#  3   Clicks       97 non-null     object
#  4   Impresiones  97 non-null     object
#  5   Views        97 non-null     object
#  6   Costo        97 non-null     object
# dtypes: object(7)
# memory usage: 5.4+ KB

# %% [markdown]
# # Extracción de datos desde bases de datos NoSQL (MongoDB)

# %%
! conda install pymongo -y
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\flavi\anaconda3\envs\tch_cf_etl_env
#
#   added / updated specs:
#     - pymongo
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cryptography-43.0.0        |  py312h89fc84f_0         1.4 MB
#     dnspython-2.4.2            |  py312haa95532_0         480 KB
#     pymongo-4.6.3              |  py312hd77b12b_0         1.2 MB
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   cryptography       pkgs/main/win-64::cryptography-43.0.0-py312h89fc84f_0
#   dnspython          pkgs/main/win-64::dnspython-2.4.2-py312haa95532_0
#   pymongo            pkgs/main/win-64::pymongo-4.6.3-py312hd77b12b_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import pymongo

client = pymongo.MongoClient('mongodb://localhost:27017/')
mydb = client['cf_etl']
mycollection = mydb['dataset']

# %%
#obtener todos los registros de la colección
for doc in mycollection.find():
    print(doc)
# Out:
# {'_id': ObjectId('66e855253d0b6a5338b09e51'), 'Fecha': datetime.datetime(2023, 12, 24, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 26148, 'Impresiones': 133468, 'Views': 21979, 'Costo': 606}
# {'_id': ObjectId('66e855253d0b6a5338b09e52'), 'Fecha': datetime.datetime(2023, 11, 11, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Norte', 'Clicks': 34586, 'Impresiones': 340290, 'Views': 49146, 'Costo': 495}
# {'_id': ObjectId('66e855253d0b6a5338b09e53'), 'Fecha': datetime.datetime(2024, 5, 24, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 20337, 'Impresiones': 343710, 'Views': 32831, 'Costo': 1655}
# {'_id': ObjectId('66e855253d0b6a5338b09e54'), 'Fecha': datetime.datetime(2023, 9, 5, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Sur', 'Clicks': 45332, 'Impresiones': 279000, 'Views': 15840, 'Costo': 991}
# {'_id': ObjectId('66e855253d0b6a5338b09e55'), 'Fecha': datetime.datetime(2024, 6, 19, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Este', 'Clicks': 36817, 'Impresiones': 462135, 'Views': 42041, 'Costo': 1784}
# {'_id': ObjectId('66e855253d0b6a5338b09e56'), 'Fecha': datetime.datetime(2023, 8, 22, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Norte', 'Clicks': 39359, 'Impresiones': 440556, 'Views': 5551, 'Costo': 205}
# {'_id': ObjectId('66e855253d0b6a5338b09e57'), 'Fecha': datetime.datetime(2024, 4, 10, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Norte', 'Clicks': 24900, 'Impresiones': 338969, 'Views': 8259, 'Costo': 134}
# {'_id': ObjectId('66e855253d0b6a5338b09e58'), 'Fecha': datetime.datetime(2023, 10, 6, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Oeste', 'Clicks': 8161, 'Impresiones': 301356, 'Views': 14102, 'Costo': 742}
# {'_id': ObjectId('66e855253d0b6a5338b09e59'), 'Fecha': datetime.datetime(2024, 3, 12, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 32254, 'Impresiones': 206296, 'Views': 6448, 'Costo': 726}
# {'_id': ObjectId('66e855253d0b6a5338b09e5a'), 'Fecha': datetime.datetime(2024, 1, 23, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Este', 'Clicks': 17853, 'Impresiones': 92740, 'Views': 6913, 'Costo': 458}
# {'_id': ObjectId('66e855253d0b6a5338b09e5b'), 'Fecha': datetime.datetime(2023, 8, 25, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Oeste', 'Clicks': 20774, 'Impresiones': 427615, 'Views': 19746, 'Costo': 1071}
# {'_id': ObjectId('66e855253d0b6a5338b09e5c'), 'Fecha': datetime.datetime(2024, 2, 15, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Norte', 'Clicks': 21897, 'Impresiones': 400482, 'Views': 13804, 'Costo': 1121}
# {'_id': ObjectId('66e855253d0b6a5338b09e5d'), 'Fecha': datetime.datetime(2024, 3, 20, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Norte', 'Clicks': 7761, 'Impresiones': 178949, 'Views': 47475, 'Costo': 862}
# {'_id': ObjectId('66e855253d0b6a5338b09e5e'), 'Fecha': datetime.datetime(2024, 1, 22, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Oeste', 'Clicks': 49693, 'Impresiones': 475089, 'Views': 30332, 'Costo': 1395}
# {'_id': ObjectId('66e855253d0b6a5338b09e5f'), 'Fecha': datetime.datetime(2024, 1, 5, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Norte', 'Clicks': 26412, 'Impresiones': 163082, 'Views': 46872, 'Costo': 970}
# {'_id': ObjectId('66e855253d0b6a5338b09e60'), 'Fecha': datetime.datetime(2024, 6, 4, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 40012, 'Impresiones': 94110, 'Views': 41153, 'Costo': 1699}
# {'_id': ObjectId('66e855253d0b6a5338b09e61'), 'Fecha': datetime.datetime(2024, 5, 21, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Este', 'Clicks': 24844, 'Impresiones': 256404, 'Views': 30079, 'Costo': 1074}
# {'_id': ObjectId('66e855253d0b6a5338b09e62'), 'Fecha': datetime.datetime(2024, 3, 31, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Norte', 'Clicks': 29111, 'Impresiones': 356257, 'Views': 7041, 'Costo': 1948}
# {'_id': ObjectId('66e855253d0b6a5338b09e63'), 'Fecha': datetime.datetime(2024, 3, 9, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 25164, 'Impresiones': 182994, 'Views': 37985, 'Costo': 1136}
# {'_id': ObjectId('66e855253d0b6a5338b09e64'), 'Fecha': datetime.datetime(2024, 6, 4, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Oeste', 'Clicks': 49036, 'Impresiones': 416554, 'Views': 22024, 'Costo': 804}
# {'_id': ObjectId('66e855253d0b6a5338b09e65'), 'Fecha': datetime.datetime(2023, 8, 13, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 34765, 'Impresiones': 198876, 'Views': 47672, 'Costo': 405}
# {'_id': ObjectId('66e855253d0b6a5338b09e66'), 'Fecha': datetime.datetime(2024, 4, 4, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 5758, 'Impresiones': 195911, 'Views': 38806, 'Costo': 696}
# {'_id': ObjectId('66e855253d0b6a5338b09e67'), 'Fecha': datetime.datetime(2023, 10, 22, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Este', 'Clicks': 42967, 'Impresiones': 356762, 'Views': 7496, 'Costo': 1722}
# {'_id': ObjectId('66e855253d0b6a5338b09e68'), 'Fecha': datetime.datetime(2024, 6, 18, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Sur', 'Clicks': 27776, 'Impresiones': 51055, 'Views': 21373, 'Costo': 158}
# {'_id': ObjectId('66e855253d0b6a5338b09e69'), 'Fecha': datetime.datetime(2024, 7, 8, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 10583, 'Impresiones': 389812, 'Views': 34221, 'Costo': 1972}
# {'_id': ObjectId('66e855253d0b6a5338b09e6a'), 'Fecha': datetime.datetime(2024, 6, 1, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 36476, 'Impresiones': 71583, 'Views': 35712, 'Costo': 1298}
# {'_id': ObjectId('66e855253d0b6a5338b09e6b'), 'Fecha': datetime.datetime(2024, 2, 28, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Sur', 'Clicks': 47048, 'Impresiones': 431736, 'Views': 36984, 'Costo': 1454}
# {'_id': ObjectId('66e855253d0b6a5338b09e6c'), 'Fecha': datetime.datetime(2024, 3, 3, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Norte', 'Clicks': 5654, 'Impresiones': 10648, 'Views': 5784, 'Costo': 744}
# {'_id': ObjectId('66e855253d0b6a5338b09e6d'), 'Fecha': datetime.datetime(2024, 5, 9, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Sur', 'Clicks': 28515, 'Impresiones': 193882, 'Views': 38421, 'Costo': 1078}
# {'_id': ObjectId('66e855253d0b6a5338b09e6e'), 'Fecha': datetime.datetime(2024, 7, 23, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Este', 'Clicks': 26493, 'Impresiones': 118214, 'Views': 20740, 'Costo': 1189}
# {'_id': ObjectId('66e855253d0b6a5338b09e6f'), 'Fecha': datetime.datetime(2024, 3, 27, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 47454, 'Impresiones': 231613, 'Views': 45405, 'Costo': 788}
# {'_id': ObjectId('66e855253d0b6a5338b09e70'), 'Fecha': datetime.datetime(2024, 7, 17, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Sur', 'Clicks': 19227, 'Impresiones': 102855, 'Views': 6645, 'Costo': 718}
# {'_id': ObjectId('66e855253d0b6a5338b09e71'), 'Fecha': datetime.datetime(2024, 3, 29, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Sur', 'Clicks': 14706, 'Impresiones': 450264, 'Views': 33294, 'Costo': 547}
# {'_id': ObjectId('66e855253d0b6a5338b09e72'), 'Fecha': datetime.datetime(2023, 11, 12, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Este', 'Clicks': 47432, 'Impresiones': 321273, 'Views': 29981, 'Costo': 1564}
# {'_id': ObjectId('66e855253d0b6a5338b09e73'), 'Fecha': datetime.datetime(2023, 11, 3, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Oeste', 'Clicks': 35772, 'Impresiones': 210854, 'Views': 14234, 'Costo': 836}
# {'_id': ObjectId('66e855253d0b6a5338b09e74'), 'Fecha': datetime.datetime(2024, 2, 19, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Norte', 'Clicks': 45961, 'Impresiones': 415096, 'Views': 31350, 'Costo': 873}
# {'_id': ObjectId('66e855253d0b6a5338b09e75'), 'Fecha': datetime.datetime(2023, 11, 13, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Oeste', 'Clicks': 47529, 'Impresiones': 354530, 'Views': 21408, 'Costo': 742}
# {'_id': ObjectId('66e855253d0b6a5338b09e76'), 'Fecha': datetime.datetime(2024, 4, 19, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 8471, 'Impresiones': 482574, 'Views': 46244, 'Costo': 696}
# {'_id': ObjectId('66e855253d0b6a5338b09e77'), 'Fecha': datetime.datetime(2024, 6, 9, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Sur', 'Clicks': 40982, 'Impresiones': 84182, 'Views': 13382, 'Costo': 1157}
# {'_id': ObjectId('66e855253d0b6a5338b09e78'), 'Fecha': datetime.datetime(2024, 3, 10, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Norte', 'Clicks': 29286, 'Impresiones': 170451, 'Views': 22374, 'Costo': 118}
# {'_id': ObjectId('66e855253d0b6a5338b09e79'), 'Fecha': datetime.datetime(2024, 1, 19, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Sur', 'Clicks': 37221, 'Impresiones': 16430, 'Views': 27746, 'Costo': 1168}
# {'_id': ObjectId('66e855253d0b6a5338b09e7a'), 'Fecha': datetime.datetime(2024, 1, 20, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 42935, 'Impresiones': 311636, 'Views': 43964, 'Costo': 1010}
# {'_id': ObjectId('66e855253d0b6a5338b09e7b'), 'Fecha': datetime.datetime(2024, 1, 22, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Este', 'Clicks': 34157, 'Impresiones': 15066, 'Views': 33269, 'Costo': 683}
# {'_id': ObjectId('66e855253d0b6a5338b09e7c'), 'Fecha': datetime.datetime(2024, 6, 25, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Este', 'Clicks': 25044, 'Impresiones': 164748, 'Views': 7319, 'Costo': 407}
# {'_id': ObjectId('66e855253d0b6a5338b09e7d'), 'Fecha': datetime.datetime(2024, 6, 26, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 11193, 'Impresiones': 110750, 'Views': 20756, 'Costo': 1602}
# {'_id': ObjectId('66e855253d0b6a5338b09e7e'), 'Fecha': datetime.datetime(2023, 9, 28, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 19950, 'Impresiones': 31002, 'Views': 46708, 'Costo': 1833}
# {'_id': ObjectId('66e855253d0b6a5338b09e7f'), 'Fecha': datetime.datetime(2024, 6, 9, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Sur', 'Clicks': 6236, 'Impresiones': 425340, 'Views': 25934, 'Costo': 1514}
# {'_id': ObjectId('66e855253d0b6a5338b09e80'), 'Fecha': datetime.datetime(2023, 10, 28, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Oeste', 'Clicks': 5564, 'Impresiones': 5563, 'Views': 16095, 'Costo': 1772}
# {'_id': ObjectId('66e855253d0b6a5338b09e81'), 'Fecha': datetime.datetime(2024, 6, 30, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Norte', 'Clicks': 43471, 'Impresiones': 490920, 'Views': 15345, 'Costo': 648}
# {'_id': ObjectId('66e855253d0b6a5338b09e82'), 'Fecha': datetime.datetime(2024, 3, 17, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Sur', 'Clicks': 49239, 'Impresiones': 165793, 'Views': 17876, 'Costo': 1889}
# {'_id': ObjectId('66e855253d0b6a5338b09e83'), 'Fecha': datetime.datetime(2024, 4, 22, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Norte', 'Clicks': 13362, 'Impresiones': 157531, 'Views': 47034, 'Costo': 517}
# {'_id': ObjectId('66e855253d0b6a5338b09e84'), 'Fecha': datetime.datetime(2024, 5, 13, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Este', 'Clicks': 9548, 'Impresiones': 107427, 'Views': 38841, 'Costo': 1695}
# {'_id': ObjectId('66e855253d0b6a5338b09e85'), 'Fecha': datetime.datetime(2024, 6, 30, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Oeste', 'Clicks': 30418, 'Impresiones': 346509, 'Views': 34367, 'Costo': 1234}
# {'_id': ObjectId('66e855253d0b6a5338b09e86'), 'Fecha': datetime.datetime(2023, 11, 30, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 36568, 'Impresiones': 342245, 'Views': 45283, 'Costo': 1778}
# {'_id': ObjectId('66e855253d0b6a5338b09e87'), 'Fecha': datetime.datetime(2024, 3, 15, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 29907, 'Impresiones': 224119, 'Views': 43715, 'Costo': 1427}
# {'_id': ObjectId('66e855253d0b6a5338b09e88'), 'Fecha': datetime.datetime(2024, 1, 27, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Este', 'Clicks': 18487, 'Impresiones': 456659, 'Views': 10762, 'Costo': 721}
# {'_id': ObjectId('66e855253d0b6a5338b09e89'), 'Fecha': datetime.datetime(2023, 8, 19, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Este', 'Clicks': 31249, 'Impresiones': 232505, 'Views': 31442, 'Costo': 816}
# {'_id': ObjectId('66e855253d0b6a5338b09e8a'), 'Fecha': datetime.datetime(2024, 3, 9, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Sur', 'Clicks': 7493, 'Impresiones': 404417, 'Views': 12996, 'Costo': 666}
# {'_id': ObjectId('66e855253d0b6a5338b09e8b'), 'Fecha': datetime.datetime(2024, 2, 29, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Oeste', 'Clicks': 19398, 'Impresiones': 111021, 'Views': 22445, 'Costo': 1827}
# {'_id': ObjectId('66e855253d0b6a5338b09e8c'), 'Fecha': datetime.datetime(2024, 7, 12, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Oeste', 'Clicks': 48336, 'Impresiones': 234716, 'Views': 9516, 'Costo': 1822}
# {'_id': ObjectId('66e855253d0b6a5338b09e8d'), 'Fecha': datetime.datetime(2023, 10, 15, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Norte', 'Clicks': 8837, 'Impresiones': 34954, 'Views': 18019, 'Costo': 455}
# {'_id': ObjectId('66e855253d0b6a5338b09e8e'), 'Fecha': datetime.datetime(2024, 2, 24, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Sur', 'Clicks': 30559, 'Impresiones': 299774, 'Views': 20999, 'Costo': 825}
# {'_id': ObjectId('66e855253d0b6a5338b09e8f'), 'Fecha': datetime.datetime(2024, 6, 13, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 25279, 'Impresiones': 50895, 'Views': 29975, 'Costo': 1463}
# {'_id': ObjectId('66e855253d0b6a5338b09e90'), 'Fecha': datetime.datetime(2023, 11, 10, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Oeste', 'Clicks': 11922, 'Impresiones': 485690, 'Views': 31750, 'Costo': 1989}
# {'_id': ObjectId('66e855253d0b6a5338b09e91'), 'Fecha': datetime.datetime(2023, 9, 24, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 36881, 'Impresiones': 451692, 'Views': 11717, 'Costo': 129}
# {'_id': ObjectId('66e855253d0b6a5338b09e92'), 'Fecha': datetime.datetime(2024, 5, 20, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Este', 'Clicks': 10055, 'Impresiones': 273392, 'Views': 34708, 'Costo': 888}
# {'_id': ObjectId('66e855253d0b6a5338b09e93'), 'Fecha': datetime.datetime(2024, 6, 30, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Este', 'Clicks': 28640, 'Impresiones': 349934, 'Views': 38199, 'Costo': 1637}
# {'_id': ObjectId('66e855253d0b6a5338b09e94'), 'Fecha': datetime.datetime(2024, 4, 4, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 44713, 'Impresiones': 393026, 'Views': 30131, 'Costo': 372}
# {'_id': ObjectId('66e855253d0b6a5338b09e95'), 'Fecha': datetime.datetime(2024, 3, 27, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Norte', 'Clicks': 8981, 'Impresiones': 157582, 'Views': 36595, 'Costo': 1187}
# {'_id': ObjectId('66e855253d0b6a5338b09e96'), 'Fecha': datetime.datetime(2024, 1, 25, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Norte', 'Clicks': 20530, 'Impresiones': 318146, 'Views': 14441, 'Costo': 1689}
# {'_id': ObjectId('66e855253d0b6a5338b09e97'), 'Fecha': datetime.datetime(2024, 4, 23, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Sur', 'Clicks': 46885, 'Impresiones': 378640, 'Views': 35032, 'Costo': 178}
# {'_id': ObjectId('66e855253d0b6a5338b09e98'), 'Fecha': datetime.datetime(2023, 12, 9, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Este', 'Clicks': 25755, 'Impresiones': 464968, 'Views': 43608, 'Costo': 372}
# {'_id': ObjectId('66e855253d0b6a5338b09e99'), 'Fecha': datetime.datetime(2023, 12, 29, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Este', 'Clicks': 37151, 'Impresiones': 64434, 'Views': 16609, 'Costo': 713}
# {'_id': ObjectId('66e855253d0b6a5338b09e9a'), 'Fecha': datetime.datetime(2024, 5, 12, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Oeste', 'Clicks': 13870, 'Impresiones': 179738, 'Views': 49795, 'Costo': 1599}
# {'_id': ObjectId('66e855253d0b6a5338b09e9b'), 'Fecha': datetime.datetime(2024, 5, 29, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Sur', 'Clicks': 15057, 'Impresiones': 290802, 'Views': 13270, 'Costo': 1101}
# {'_id': ObjectId('66e855253d0b6a5338b09e9c'), 'Fecha': datetime.datetime(2023, 12, 26, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Norte', 'Clicks': 40493, 'Impresiones': 117904, 'Views': 26707, 'Costo': 1116}
# {'_id': ObjectId('66e855253d0b6a5338b09e9d'), 'Fecha': datetime.datetime(2023, 9, 5, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Este', 'Clicks': 35000, 'Impresiones': 70546, 'Views': 38366, 'Costo': 1983}
# {'_id': ObjectId('66e855253d0b6a5338b09e9e'), 'Fecha': datetime.datetime(2024, 1, 24, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Este', 'Clicks': 40931, 'Impresiones': 420975, 'Views': 7543, 'Costo': 173}
# {'_id': ObjectId('66e855253d0b6a5338b09e9f'), 'Fecha': datetime.datetime(2023, 9, 2, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Sur', 'Clicks': 44422, 'Impresiones': 481029, 'Views': 24094, 'Costo': 772}
# {'_id': ObjectId('66e855253d0b6a5338b09ea0'), 'Fecha': datetime.datetime(2024, 5, 9, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Sur', 'Clicks': 27964, 'Impresiones': 236841, 'Views': 27533, 'Costo': 559}
# {'_id': ObjectId('66e855253d0b6a5338b09ea1'), 'Fecha': datetime.datetime(2023, 10, 30, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Norte', 'Clicks': 43028, 'Impresiones': 39998, 'Views': 42763, 'Costo': 1837}
# {'_id': ObjectId('66e855253d0b6a5338b09ea2'), 'Fecha': datetime.datetime(2024, 2, 19, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Norte', 'Clicks': 33265, 'Impresiones': 250594, 'Views': 40133, 'Costo': 1960}
# {'_id': ObjectId('66e855253d0b6a5338b09ea3'), 'Fecha': datetime.datetime(2024, 7, 28, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Este', 'Clicks': 12759, 'Impresiones': 85516, 'Views': 48625, 'Costo': 1349}
# {'_id': ObjectId('66e855253d0b6a5338b09ea4'), 'Fecha': datetime.datetime(2024, 2, 7, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Este', 'Clicks': 14063, 'Impresiones': 348207, 'Views': 31433, 'Costo': 1065}
# {'_id': ObjectId('66e855253d0b6a5338b09ea5'), 'Fecha': datetime.datetime(2024, 4, 2, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Este', 'Clicks': 29151, 'Impresiones': 326245, 'Views': 14170, 'Costo': 364}
# {'_id': ObjectId('66e855253d0b6a5338b09ea6'), 'Fecha': datetime.datetime(2023, 8, 15, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Sur', 'Clicks': 15005, 'Impresiones': 134446, 'Views': 37950, 'Costo': 1898}
# {'_id': ObjectId('66e855253d0b6a5338b09ea7'), 'Fecha': datetime.datetime(2024, 5, 19, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 48086, 'Impresiones': 203627, 'Views': 12443, 'Costo': 138}
# {'_id': ObjectId('66e855253d0b6a5338b09ea8'), 'Fecha': datetime.datetime(2024, 5, 29, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Sur', 'Clicks': 31664, 'Impresiones': 104786, 'Views': 24615, 'Costo': 795}
# {'_id': ObjectId('66e855253d0b6a5338b09ea9'), 'Fecha': datetime.datetime(2024, 7, 1, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 20017, 'Impresiones': 124371, 'Views': 37821, 'Costo': 1015}
# {'_id': ObjectId('66e855253d0b6a5338b09eaa'), 'Fecha': datetime.datetime(2023, 10, 17, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Este', 'Clicks': 28731, 'Impresiones': 187565, 'Views': 46658, 'Costo': 1334}
# {'_id': ObjectId('66e855253d0b6a5338b09eab'), 'Fecha': datetime.datetime(2023, 9, 30, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Norte', 'Clicks': 10651, 'Impresiones': 477033, 'Views': 14515, 'Costo': 1528}
# {'_id': ObjectId('66e855253d0b6a5338b09eac'), 'Fecha': datetime.datetime(2024, 2, 24, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Oeste', 'Clicks': 15152, 'Impresiones': 11819, 'Views': 44474, 'Costo': 427}
# {'_id': ObjectId('66e855253d0b6a5338b09ead'), 'Fecha': datetime.datetime(2024, 3, 26, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 43967, 'Impresiones': 73242, 'Views': 47674, 'Costo': 644}
# {'_id': ObjectId('66e855253d0b6a5338b09eae'), 'Fecha': datetime.datetime(2024, 7, 25, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 8075, 'Impresiones': 396766, 'Views': 12265, 'Costo': 1835}
# {'_id': ObjectId('66e855253d0b6a5338b09eaf'), 'Fecha': datetime.datetime(2024, 7, 7, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 22899, 'Impresiones': 46593, 'Views': 44606, 'Costo': 1187}
# {'_id': ObjectId('66e855253d0b6a5338b09eb0'), 'Fecha': datetime.datetime(2024, 1, 23, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 23855, 'Impresiones': 384818, 'Views': 18835, 'Costo': 229}
# {'_id': ObjectId('66e855253d0b6a5338b09eb1'), 'Fecha': datetime.datetime(2023, 12, 17, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Oeste', 'Clicks': 46108, 'Impresiones': 22779, 'Views': 21223, 'Costo': 1195}
# {'_id': ObjectId('66e855253d0b6a5338b09eb2'), 'Fecha': datetime.datetime(2023, 10, 19, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Norte', 'Clicks': 28925, 'Impresiones': 348255, 'Views': 17454, 'Costo': 1974}
# {'_id': ObjectId('66e855253d0b6a5338b09eb3'), 'Fecha': datetime.datetime(2024, 5, 20, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Oeste', 'Clicks': 14136, 'Impresiones': 102905, 'Views': 38875, 'Costo': 1971}
# {'_id': ObjectId('66e855253d0b6a5338b09eb4'), 'Fecha': datetime.datetime(2024, 6, 14, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Sur', 'Clicks': 22284, 'Impresiones': 329007, 'Views': 48629, 'Costo': 1938}
# {'_id': ObjectId('66e855253d0b6a5338b09eb5'), 'Fecha': datetime.datetime(2024, 7, 27, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 6428, 'Impresiones': 151577, 'Views': 38916, 'Costo': 159}
# {'_id': ObjectId('66e855253d0b6a5338b09eb6'), 'Fecha': datetime.datetime(2023, 11, 15, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 5979, 'Impresiones': 358826, 'Views': 6126, 'Costo': 1168}
# {'_id': ObjectId('66e855253d0b6a5338b09eb7'), 'Fecha': datetime.datetime(2024, 7, 7, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 40957, 'Impresiones': 444603, 'Views': 43199, 'Costo': 1344}
# {'_id': ObjectId('66e855253d0b6a5338b09eb8'), 'Fecha': datetime.datetime(2024, 2, 24, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 17844, 'Impresiones': 395847, 'Views': 33896, 'Costo': 870}
# {'_id': ObjectId('66e855253d0b6a5338b09eb9'), 'Fecha': datetime.datetime(2024, 2, 10, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Este', 'Clicks': 22139, 'Impresiones': 315539, 'Views': 12123, 'Costo': 439}
# {'_id': ObjectId('66e855253d0b6a5338b09eba'), 'Fecha': datetime.datetime(2024, 1, 16, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Norte', 'Clicks': 48017, 'Impresiones': 140533, 'Views': 36556, 'Costo': 1014}
# {'_id': ObjectId('66e855253d0b6a5338b09ebb'), 'Fecha': datetime.datetime(2024, 6, 29, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Este', 'Clicks': 38953, 'Impresiones': 469810, 'Views': 29584, 'Costo': 995}
# {'_id': ObjectId('66e855253d0b6a5338b09ebc'), 'Fecha': datetime.datetime(2024, 4, 7, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Sur', 'Clicks': 20586, 'Impresiones': 344823, 'Views': 27472, 'Costo': 1523}
# {'_id': ObjectId('66e855253d0b6a5338b09ebd'), 'Fecha': datetime.datetime(2024, 5, 6, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Este', 'Clicks': 19101, 'Impresiones': 28632, 'Views': 23421, 'Costo': 353}
# {'_id': ObjectId('66e855253d0b6a5338b09ebe'), 'Fecha': datetime.datetime(2024, 3, 28, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Sur', 'Clicks': 13097, 'Impresiones': 281145, 'Views': 36147, 'Costo': 910}
# {'_id': ObjectId('66e855253d0b6a5338b09ebf'), 'Fecha': datetime.datetime(2023, 9, 30, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 29205, 'Impresiones': 485595, 'Views': 19260, 'Costo': 1257}
# {'_id': ObjectId('66e855253d0b6a5338b09ec0'), 'Fecha': datetime.datetime(2024, 6, 27, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Este', 'Clicks': 22006, 'Impresiones': 227671, 'Views': 37650, 'Costo': 1839}
# {'_id': ObjectId('66e855253d0b6a5338b09ec1'), 'Fecha': datetime.datetime(2024, 1, 19, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Sur', 'Clicks': 13549, 'Impresiones': 25526, 'Views': 20377, 'Costo': 213}
# {'_id': ObjectId('66e855253d0b6a5338b09ec2'), 'Fecha': datetime.datetime(2023, 9, 5, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 11943, 'Impresiones': 15235, 'Views': 46896, 'Costo': 479}
# {'_id': ObjectId('66e855253d0b6a5338b09ec3'), 'Fecha': datetime.datetime(2024, 3, 13, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Sur', 'Clicks': 14592, 'Impresiones': 484634, 'Views': 7958, 'Costo': 841}
# {'_id': ObjectId('66e855253d0b6a5338b09ec4'), 'Fecha': datetime.datetime(2024, 4, 23, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Norte', 'Clicks': 27250, 'Impresiones': 485422, 'Views': 29484, 'Costo': 759}
# {'_id': ObjectId('66e855253d0b6a5338b09ec5'), 'Fecha': datetime.datetime(2023, 11, 9, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Este', 'Clicks': 48907, 'Impresiones': 105129, 'Views': 29753, 'Costo': 1002}
# {'_id': ObjectId('66e855253d0b6a5338b09ec6'), 'Fecha': datetime.datetime(2024, 1, 3, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 47233, 'Impresiones': 65128, 'Views': 16932, 'Costo': 1333}
# {'_id': ObjectId('66e855253d0b6a5338b09ec7'), 'Fecha': datetime.datetime(2023, 10, 6, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Este', 'Clicks': 41704, 'Impresiones': 427054, 'Views': 14475, 'Costo': 1910}
# {'_id': ObjectId('66e855253d0b6a5338b09ec8'), 'Fecha': datetime.datetime(2023, 8, 25, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Este', 'Clicks': 6234, 'Impresiones': 155481, 'Views': 25739, 'Costo': 761}
# {'_id': ObjectId('66e855253d0b6a5338b09ec9'), 'Fecha': datetime.datetime(2024, 5, 17, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 14561, 'Impresiones': 291611, 'Views': 9462, 'Costo': 252}
# {'_id': ObjectId('66e855253d0b6a5338b09eca'), 'Fecha': datetime.datetime(2023, 10, 20, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Oeste', 'Clicks': 24395, 'Impresiones': 96351, 'Views': 5157, 'Costo': 875}
# {'_id': ObjectId('66e855253d0b6a5338b09ecb'), 'Fecha': datetime.datetime(2024, 4, 21, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Sur', 'Clicks': 9370, 'Impresiones': 302492, 'Views': 37744, 'Costo': 1249}
# {'_id': ObjectId('66e855253d0b6a5338b09ecc'), 'Fecha': datetime.datetime(2023, 10, 11, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 25211, 'Impresiones': 114535, 'Views': 8659, 'Costo': 796}
# {'_id': ObjectId('66e855253d0b6a5338b09ecd'), 'Fecha': datetime.datetime(2023, 12, 16, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Oeste', 'Clicks': 22732, 'Impresiones': 28363, 'Views': 31377, 'Costo': 803}
# {'_id': ObjectId('66e855253d0b6a5338b09ece'), 'Fecha': datetime.datetime(2023, 12, 18, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Sur', 'Clicks': 33503, 'Impresiones': 436603, 'Views': 29349, 'Costo': 466}
# {'_id': ObjectId('66e855253d0b6a5338b09ecf'), 'Fecha': datetime.datetime(2024, 5, 29, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Norte', 'Clicks': 12857, 'Impresiones': 330437, 'Views': 30191, 'Costo': 1863}
# {'_id': ObjectId('66e855253d0b6a5338b09ed0'), 'Fecha': datetime.datetime(2024, 4, 24, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Norte', 'Clicks': 11397, 'Impresiones': 412292, 'Views': 15505, 'Costo': 509}
# {'_id': ObjectId('66e855253d0b6a5338b09ed1'), 'Fecha': datetime.datetime(2023, 12, 14, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Oeste', 'Clicks': 29512, 'Impresiones': 22176, 'Views': 6459, 'Costo': 641}
# {'_id': ObjectId('66e855253d0b6a5338b09ed2'), 'Fecha': datetime.datetime(2024, 1, 20, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Norte', 'Clicks': 11691, 'Impresiones': 351592, 'Views': 41499, 'Costo': 137}
# {'_id': ObjectId('66e855253d0b6a5338b09ed3'), 'Fecha': datetime.datetime(2023, 9, 20, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 43769, 'Impresiones': 201069, 'Views': 12882, 'Costo': 1641}
# {'_id': ObjectId('66e855253d0b6a5338b09ed4'), 'Fecha': datetime.datetime(2023, 10, 2, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Este', 'Clicks': 29652, 'Impresiones': 471449, 'Views': 22526, 'Costo': 1832}
# {'_id': ObjectId('66e855253d0b6a5338b09ed5'), 'Fecha': datetime.datetime(2023, 9, 2, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Norte', 'Clicks': 12791, 'Impresiones': 54500, 'Views': 38331, 'Costo': 1379}
# {'_id': ObjectId('66e855253d0b6a5338b09ed6'), 'Fecha': datetime.datetime(2024, 4, 6, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Norte', 'Clicks': 23294, 'Impresiones': 282996, 'Views': 24528, 'Costo': 239}
# {'_id': ObjectId('66e855253d0b6a5338b09ed7'), 'Fecha': datetime.datetime(2024, 1, 7, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Sur', 'Clicks': 46128, 'Impresiones': 205353, 'Views': 38895, 'Costo': 1734}
# {'_id': ObjectId('66e855253d0b6a5338b09ed8'), 'Fecha': datetime.datetime(2024, 4, 21, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 44536, 'Impresiones': 365536, 'Views': 28824, 'Costo': 407}
# {'_id': ObjectId('66e855253d0b6a5338b09ed9'), 'Fecha': datetime.datetime(2024, 6, 3, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Sur', 'Clicks': 27691, 'Impresiones': 407145, 'Views': 12034, 'Costo': 1404}
# {'_id': ObjectId('66e855253d0b6a5338b09eda'), 'Fecha': datetime.datetime(2024, 1, 1, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 15921, 'Impresiones': 441081, 'Views': 23443, 'Costo': 1525}
# {'_id': ObjectId('66e855253d0b6a5338b09edb'), 'Fecha': datetime.datetime(2024, 1, 20, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Este', 'Clicks': 9511, 'Impresiones': 107506, 'Views': 34191, 'Costo': 1291}
# {'_id': ObjectId('66e855253d0b6a5338b09edc'), 'Fecha': datetime.datetime(2023, 12, 7, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 12996, 'Impresiones': 340559, 'Views': 15542, 'Costo': 921}
# {'_id': ObjectId('66e855253d0b6a5338b09edd'), 'Fecha': datetime.datetime(2024, 2, 10, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Oeste', 'Clicks': 47441, 'Impresiones': 290016, 'Views': 19316, 'Costo': 1421}
# {'_id': ObjectId('66e855253d0b6a5338b09ede'), 'Fecha': datetime.datetime(2024, 5, 18, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Sur', 'Clicks': 33544, 'Impresiones': 337868, 'Views': 34909, 'Costo': 904}
# {'_id': ObjectId('66e855253d0b6a5338b09edf'), 'Fecha': datetime.datetime(2024, 6, 26, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Oeste', 'Clicks': 32928, 'Impresiones': 80341, 'Views': 30678, 'Costo': 1573}
# {'_id': ObjectId('66e855253d0b6a5338b09ee0'), 'Fecha': datetime.datetime(2024, 3, 6, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Norte', 'Clicks': 44000, 'Impresiones': 305094, 'Views': 14018, 'Costo': 1856}
# {'_id': ObjectId('66e855253d0b6a5338b09ee1'), 'Fecha': datetime.datetime(2023, 12, 4, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Este', 'Clicks': 19175, 'Impresiones': 103432, 'Views': 46434, 'Costo': 1796}
# {'_id': ObjectId('66e855253d0b6a5338b09ee2'), 'Fecha': datetime.datetime(2024, 2, 17, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 47531, 'Impresiones': 76091, 'Views': 49155, 'Costo': 151}
# {'_id': ObjectId('66e855253d0b6a5338b09ee3'), 'Fecha': datetime.datetime(2024, 5, 25, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Sur', 'Clicks': 23701, 'Impresiones': 185716, 'Views': 43248, 'Costo': 1909}
# {'_id': ObjectId('66e855253d0b6a5338b09ee4'), 'Fecha': datetime.datetime(2024, 6, 26, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Este', 'Clicks': 32917, 'Impresiones': 112493, 'Views': 7570, 'Costo': 1968}
# {'_id': ObjectId('66e855253d0b6a5338b09ee5'), 'Fecha': datetime.datetime(2024, 2, 7, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Sur', 'Clicks': 12786, 'Impresiones': 401991, 'Views': 13626, 'Costo': 388}
# {'_id': ObjectId('66e855253d0b6a5338b09ee6'), 'Fecha': datetime.datetime(2023, 11, 27, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 21209, 'Impresiones': 338962, 'Views': 45821, 'Costo': 1605}
# {'_id': ObjectId('66e855253d0b6a5338b09ee7'), 'Fecha': datetime.datetime(2023, 8, 30, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Norte', 'Clicks': 40947, 'Impresiones': 118009, 'Views': 37161, 'Costo': 1483}
# {'_id': ObjectId('66e855253d0b6a5338b09ee8'), 'Fecha': datetime.datetime(2024, 2, 25, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 36621, 'Impresiones': 149145, 'Views': 45645, 'Costo': 437}
# {'_id': ObjectId('66e855253d0b6a5338b09ee9'), 'Fecha': datetime.datetime(2024, 7, 2, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Oeste', 'Clicks': 19351, 'Impresiones': 79587, 'Views': 40902, 'Costo': 655}
# {'_id': ObjectId('66e855253d0b6a5338b09eea'), 'Fecha': datetime.datetime(2023, 12, 20, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 27213, 'Impresiones': 173214, 'Views': 41129, 'Costo': 403}
# {'_id': ObjectId('66e855253d0b6a5338b09eeb'), 'Fecha': datetime.datetime(2024, 2, 28, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 27780, 'Impresiones': 442073, 'Views': 5330, 'Costo': 1054}
# {'_id': ObjectId('66e855253d0b6a5338b09eec'), 'Fecha': datetime.datetime(2023, 8, 20, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Norte', 'Clicks': 41833, 'Impresiones': 379357, 'Views': 31635, 'Costo': 698}
# {'_id': ObjectId('66e855253d0b6a5338b09eed'), 'Fecha': datetime.datetime(2023, 11, 23, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Este', 'Clicks': 14827, 'Impresiones': 491364, 'Views': 30224, 'Costo': 788}
# {'_id': ObjectId('66e855253d0b6a5338b09eee'), 'Fecha': datetime.datetime(2023, 10, 10, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 44707, 'Impresiones': 18023, 'Views': 36757, 'Costo': 897}
# {'_id': ObjectId('66e855253d0b6a5338b09eef'), 'Fecha': datetime.datetime(2024, 5, 15, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Oeste', 'Clicks': 27232, 'Impresiones': 496137, 'Views': 49765, 'Costo': 200}
# {'_id': ObjectId('66e855253d0b6a5338b09ef0'), 'Fecha': datetime.datetime(2024, 7, 9, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Oeste', 'Clicks': 8955, 'Impresiones': 103256, 'Views': 26295, 'Costo': 444}
# {'_id': ObjectId('66e855253d0b6a5338b09ef1'), 'Fecha': datetime.datetime(2024, 2, 13, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 27468, 'Impresiones': 183753, 'Views': 41787, 'Costo': 358}
# {'_id': ObjectId('66e855253d0b6a5338b09ef2'), 'Fecha': datetime.datetime(2024, 5, 28, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Sur', 'Clicks': 28708, 'Impresiones': 411926, 'Views': 20569, 'Costo': 1544}
# {'_id': ObjectId('66e855253d0b6a5338b09ef3'), 'Fecha': datetime.datetime(2023, 12, 15, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Norte', 'Clicks': 43672, 'Impresiones': 195429, 'Views': 26026, 'Costo': 252}
# {'_id': ObjectId('66e855253d0b6a5338b09ef4'), 'Fecha': datetime.datetime(2024, 8, 9, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Este', 'Clicks': 45278, 'Impresiones': 49835, 'Views': 31935, 'Costo': 534}
# {'_id': ObjectId('66e855253d0b6a5338b09ef5'), 'Fecha': datetime.datetime(2024, 3, 25, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Oeste', 'Clicks': 14166, 'Impresiones': 291170, 'Views': 33329, 'Costo': 1256}
# {'_id': ObjectId('66e855253d0b6a5338b09ef6'), 'Fecha': datetime.datetime(2023, 11, 18, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Norte', 'Clicks': 16482, 'Impresiones': 257260, 'Views': 21028, 'Costo': 1870}
# {'_id': ObjectId('66e855253d0b6a5338b09ef7'), 'Fecha': datetime.datetime(2024, 7, 12, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 39872, 'Impresiones': 265021, 'Views': 21379, 'Costo': 570}
# {'_id': ObjectId('66e855253d0b6a5338b09ef8'), 'Fecha': datetime.datetime(2023, 9, 9, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Este', 'Clicks': 22477, 'Impresiones': 233948, 'Views': 17754, 'Costo': 299}
# {'_id': ObjectId('66e855253d0b6a5338b09ef9'), 'Fecha': datetime.datetime(2024, 1, 22, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Este', 'Clicks': 48785, 'Impresiones': 141066, 'Views': 40599, 'Costo': 520}
# {'_id': ObjectId('66e855253d0b6a5338b09efa'), 'Fecha': datetime.datetime(2024, 8, 10, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Norte', 'Clicks': 40266, 'Impresiones': 359320, 'Views': 10677, 'Costo': 1943}
# {'_id': ObjectId('66e855253d0b6a5338b09efb'), 'Fecha': datetime.datetime(2024, 4, 19, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Este', 'Clicks': 12110, 'Impresiones': 485228, 'Views': 10174, 'Costo': 1046}
# {'_id': ObjectId('66e855253d0b6a5338b09efc'), 'Fecha': datetime.datetime(2024, 4, 6, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 31057, 'Impresiones': 179812, 'Views': 11160, 'Costo': 1629}
# {'_id': ObjectId('66e855253d0b6a5338b09efd'), 'Fecha': datetime.datetime(2023, 8, 24, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Norte', 'Clicks': 22956, 'Impresiones': 184108, 'Views': 6322, 'Costo': 1375}
# {'_id': ObjectId('66e855253d0b6a5338b09efe'), 'Fecha': datetime.datetime(2024, 6, 16, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Este', 'Clicks': 32500, 'Impresiones': 53792, 'Views': 44183, 'Costo': 1982}
# {'_id': ObjectId('66e855253d0b6a5338b09eff'), 'Fecha': datetime.datetime(2023, 11, 16, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 13506, 'Impresiones': 38407, 'Views': 6753, 'Costo': 1518}
# {'_id': ObjectId('66e855253d0b6a5338b09f00'), 'Fecha': datetime.datetime(2023, 9, 24, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Oeste', 'Clicks': 16787, 'Impresiones': 52975, 'Views': 19669, 'Costo': 196}
# {'_id': ObjectId('66e855253d0b6a5338b09f01'), 'Fecha': datetime.datetime(2023, 11, 27, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Oeste', 'Clicks': 8665, 'Impresiones': 136843, 'Views': 9246, 'Costo': 1595}
# {'_id': ObjectId('66e855253d0b6a5338b09f02'), 'Fecha': datetime.datetime(2024, 4, 23, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Norte', 'Clicks': 41091, 'Impresiones': 30873, 'Views': 46682, 'Costo': 767}
# {'_id': ObjectId('66e855253d0b6a5338b09f03'), 'Fecha': datetime.datetime(2023, 11, 17, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 39705, 'Impresiones': 244416, 'Views': 19264, 'Costo': 1320}
# {'_id': ObjectId('66e855253d0b6a5338b09f04'), 'Fecha': datetime.datetime(2023, 12, 18, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 9199, 'Impresiones': 494277, 'Views': 28425, 'Costo': 1584}
# {'_id': ObjectId('66e855253d0b6a5338b09f05'), 'Fecha': datetime.datetime(2023, 12, 2, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 28783, 'Impresiones': 35037, 'Views': 38663, 'Costo': 1743}
# {'_id': ObjectId('66e855253d0b6a5338b09f06'), 'Fecha': datetime.datetime(2024, 7, 8, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Sur', 'Clicks': 44006, 'Impresiones': 458221, 'Views': 12265, 'Costo': 742}
# {'_id': ObjectId('66e855253d0b6a5338b09f07'), 'Fecha': datetime.datetime(2024, 5, 19, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Oeste', 'Clicks': 48016, 'Impresiones': 102687, 'Views': 6419, 'Costo': 742}
# {'_id': ObjectId('66e855253d0b6a5338b09f08'), 'Fecha': datetime.datetime(2024, 4, 24, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Sur', 'Clicks': 15710, 'Impresiones': 9825, 'Views': 36737, 'Costo': 715}
# {'_id': ObjectId('66e855253d0b6a5338b09f09'), 'Fecha': datetime.datetime(2024, 4, 28, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Norte', 'Clicks': 24047, 'Impresiones': 308436, 'Views': 20499, 'Costo': 221}
# {'_id': ObjectId('66e855253d0b6a5338b09f0a'), 'Fecha': datetime.datetime(2024, 5, 30, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Sur', 'Clicks': 8997, 'Impresiones': 212040, 'Views': 27660, 'Costo': 372}
# {'_id': ObjectId('66e855253d0b6a5338b09f0b'), 'Fecha': datetime.datetime(2024, 3, 3, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Norte', 'Clicks': 20211, 'Impresiones': 50727, 'Views': 10991, 'Costo': 573}
# {'_id': ObjectId('66e855253d0b6a5338b09f0c'), 'Fecha': datetime.datetime(2023, 8, 11, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 48925, 'Impresiones': 73605, 'Views': 10735, 'Costo': 1962}
# {'_id': ObjectId('66e855253d0b6a5338b09f0d'), 'Fecha': datetime.datetime(2024, 1, 1, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 15325, 'Impresiones': 108214, 'Views': 49528, 'Costo': 273}
# {'_id': ObjectId('66e855253d0b6a5338b09f0e'), 'Fecha': datetime.datetime(2024, 4, 30, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Este', 'Clicks': 7225, 'Impresiones': 328736, 'Views': 5510, 'Costo': 797}
# {'_id': ObjectId('66e855253d0b6a5338b09f0f'), 'Fecha': datetime.datetime(2024, 2, 10, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 30697, 'Impresiones': 91000, 'Views': 49836, 'Costo': 257}
# {'_id': ObjectId('66e855253d0b6a5338b09f10'), 'Fecha': datetime.datetime(2024, 6, 16, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Este', 'Clicks': 41720, 'Impresiones': 315816, 'Views': 41016, 'Costo': 1452}
# {'_id': ObjectId('66e855253d0b6a5338b09f11'), 'Fecha': datetime.datetime(2023, 11, 29, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Norte', 'Clicks': 37975, 'Impresiones': 283531, 'Views': 30930, 'Costo': 446}
# {'_id': ObjectId('66e855253d0b6a5338b09f12'), 'Fecha': datetime.datetime(2023, 8, 21, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Este', 'Clicks': 39868, 'Impresiones': 209561, 'Views': 46728, 'Costo': 1275}
# {'_id': ObjectId('66e855253d0b6a5338b09f13'), 'Fecha': datetime.datetime(2024, 4, 28, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 45032, 'Impresiones': 196403, 'Views': 5051, 'Costo': 946}
# {'_id': ObjectId('66e855253d0b6a5338b09f14'), 'Fecha': datetime.datetime(2024, 6, 20, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Norte', 'Clicks': 18983, 'Impresiones': 241383, 'Views': 23334, 'Costo': 1405}
# {'_id': ObjectId('66e855253d0b6a5338b09f15'), 'Fecha': datetime.datetime(2023, 12, 19, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 32013, 'Impresiones': 53658, 'Views': 33919, 'Costo': 1883}
# {'_id': ObjectId('66e855253d0b6a5338b09f16'), 'Fecha': datetime.datetime(2024, 5, 14, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 9834, 'Impresiones': 416727, 'Views': 12695, 'Costo': 561}
# {'_id': ObjectId('66e855253d0b6a5338b09f17'), 'Fecha': datetime.datetime(2024, 5, 26, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Norte', 'Clicks': 19953, 'Impresiones': 43204, 'Views': 35759, 'Costo': 991}
# {'_id': ObjectId('66e855253d0b6a5338b09f18'), 'Fecha': datetime.datetime(2024, 5, 31, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 19522, 'Impresiones': 105869, 'Views': 18707, 'Costo': 1439}
# {'_id': ObjectId('66e855253d0b6a5338b09f19'), 'Fecha': datetime.datetime(2024, 3, 10, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Sur', 'Clicks': 13972, 'Impresiones': 447338, 'Views': 15355, 'Costo': 630}
# {'_id': ObjectId('66e855253d0b6a5338b09f1a'), 'Fecha': datetime.datetime(2024, 2, 5, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 33728, 'Impresiones': 147790, 'Views': 32162, 'Costo': 998}
# {'_id': ObjectId('66e855253d0b6a5338b09f1b'), 'Fecha': datetime.datetime(2023, 11, 5, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Oeste', 'Clicks': 6124, 'Impresiones': 111451, 'Views': 10043, 'Costo': 1240}
# {'_id': ObjectId('66e855253d0b6a5338b09f1c'), 'Fecha': datetime.datetime(2024, 3, 20, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Sur', 'Clicks': 30095, 'Impresiones': 392846, 'Views': 18152, 'Costo': 1456}
# {'_id': ObjectId('66e855253d0b6a5338b09f1d'), 'Fecha': datetime.datetime(2024, 3, 15, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Este', 'Clicks': 38310, 'Impresiones': 74048, 'Views': 18087, 'Costo': 1162}
# {'_id': ObjectId('66e855253d0b6a5338b09f1e'), 'Fecha': datetime.datetime(2024, 3, 9, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 48614, 'Impresiones': 124857, 'Views': 27003, 'Costo': 360}
# {'_id': ObjectId('66e855253d0b6a5338b09f1f'), 'Fecha': datetime.datetime(2024, 5, 22, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Sur', 'Clicks': 13715, 'Impresiones': 499070, 'Views': 16774, 'Costo': 1717}
# {'_id': ObjectId('66e855253d0b6a5338b09f20'), 'Fecha': datetime.datetime(2023, 12, 6, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Este', 'Clicks': 22166, 'Impresiones': 80353, 'Views': 17657, 'Costo': 767}
# {'_id': ObjectId('66e855253d0b6a5338b09f21'), 'Fecha': datetime.datetime(2024, 7, 22, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Sur', 'Clicks': 17626, 'Impresiones': 239926, 'Views': 27715, 'Costo': 782}
# ...
# {'_id': ObjectId('66e855253d0b6a5338b0a1f4'), 'Fecha': datetime.datetime(2024, 3, 11, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Norte', 'Clicks': 32144, 'Impresiones': 367630, 'Views': 8837, 'Costo': 1893}
# {'_id': ObjectId('66e855253d0b6a5338b0a1f5'), 'Fecha': datetime.datetime(2024, 3, 5, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Norte', 'Clicks': 38144, 'Impresiones': 388114, 'Views': 9738, 'Costo': 1760}
# {'_id': ObjectId('66e855253d0b6a5338b0a1f6'), 'Fecha': datetime.datetime(2023, 12, 8, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Este', 'Clicks': 40148, 'Impresiones': 40292, 'Views': 33910, 'Costo': 1702}
# {'_id': ObjectId('66e855253d0b6a5338b0a1f7'), 'Fecha': datetime.datetime(2023, 11, 12, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Oeste', 'Clicks': 18721, 'Impresiones': 231394, 'Views': 19487, 'Costo': 635}
# {'_id': ObjectId('66e855253d0b6a5338b0a1f8'), 'Fecha': datetime.datetime(2024, 5, 11, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Sur', 'Clicks': 44451, 'Impresiones': 49155, 'Views': 36607, 'Costo': 1796}
# {'_id': ObjectId('66e855253d0b6a5338b0a1f9'), 'Fecha': datetime.datetime(2023, 10, 14, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 27390, 'Impresiones': 89655, 'Views': 5149, 'Costo': 184}
# {'_id': ObjectId('66e855253d0b6a5338b0a1fa'), 'Fecha': datetime.datetime(2024, 3, 17, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Este', 'Clicks': 11631, 'Impresiones': 206358, 'Views': 30567, 'Costo': 744}
# {'_id': ObjectId('66e855253d0b6a5338b0a1fb'), 'Fecha': datetime.datetime(2023, 8, 18, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Este', 'Clicks': 29924, 'Impresiones': 286338, 'Views': 5087, 'Costo': 1511}
# {'_id': ObjectId('66e855253d0b6a5338b0a1fc'), 'Fecha': datetime.datetime(2024, 1, 4, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Este', 'Clicks': 47722, 'Impresiones': 21788, 'Views': 35984, 'Costo': 1375}
# {'_id': ObjectId('66e855253d0b6a5338b0a1fd'), 'Fecha': datetime.datetime(2024, 6, 13, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 45909, 'Impresiones': 497497, 'Views': 10085, 'Costo': 1444}
# {'_id': ObjectId('66e855253d0b6a5338b0a1fe'), 'Fecha': datetime.datetime(2023, 10, 30, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Oeste', 'Clicks': 18323, 'Impresiones': 102445, 'Views': 39620, 'Costo': 608}
# {'_id': ObjectId('66e855253d0b6a5338b0a1ff'), 'Fecha': datetime.datetime(2023, 12, 30, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Este', 'Clicks': 41364, 'Impresiones': 396999, 'Views': 37389, 'Costo': 1777}
# {'_id': ObjectId('66e855253d0b6a5338b0a200'), 'Fecha': datetime.datetime(2024, 5, 18, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 22108, 'Impresiones': 96126, 'Views': 13698, 'Costo': 1767}
# {'_id': ObjectId('66e855253d0b6a5338b0a201'), 'Fecha': datetime.datetime(2024, 1, 12, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 6405, 'Impresiones': 257092, 'Views': 26387, 'Costo': 480}
# {'_id': ObjectId('66e855253d0b6a5338b0a202'), 'Fecha': datetime.datetime(2023, 9, 3, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Sur', 'Clicks': 5661, 'Impresiones': 181136, 'Views': 11163, 'Costo': 1449}
# {'_id': ObjectId('66e855253d0b6a5338b0a203'), 'Fecha': datetime.datetime(2023, 10, 24, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Sur', 'Clicks': 35121, 'Impresiones': 435129, 'Views': 7585, 'Costo': 450}
# {'_id': ObjectId('66e855253d0b6a5338b0a204'), 'Fecha': datetime.datetime(2024, 5, 22, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Sur', 'Clicks': 11518, 'Impresiones': 463535, 'Views': 39136, 'Costo': 1420}
# {'_id': ObjectId('66e855253d0b6a5338b0a205'), 'Fecha': datetime.datetime(2024, 7, 5, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Este', 'Clicks': 34709, 'Impresiones': 406310, 'Views': 8394, 'Costo': 1637}
# {'_id': ObjectId('66e855253d0b6a5338b0a206'), 'Fecha': datetime.datetime(2023, 11, 13, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Oeste', 'Clicks': 23836, 'Impresiones': 388636, 'Views': 13133, 'Costo': 1434}
# {'_id': ObjectId('66e855253d0b6a5338b0a207'), 'Fecha': datetime.datetime(2023, 12, 27, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Sur', 'Clicks': 7657, 'Impresiones': 291640, 'Views': 17080, 'Costo': 1324}
# {'_id': ObjectId('66e855253d0b6a5338b0a208'), 'Fecha': datetime.datetime(2024, 3, 22, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Oeste', 'Clicks': 49190, 'Impresiones': 317620, 'Views': 22282, 'Costo': 1067}
# {'_id': ObjectId('66e855253d0b6a5338b0a209'), 'Fecha': datetime.datetime(2023, 10, 9, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Oeste', 'Clicks': 33856, 'Impresiones': 293242, 'Views': 32136, 'Costo': 1597}
# {'_id': ObjectId('66e855253d0b6a5338b0a20a'), 'Fecha': datetime.datetime(2024, 5, 24, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 31765, 'Impresiones': 160407, 'Views': 21644, 'Costo': 827}
# {'_id': ObjectId('66e855253d0b6a5338b0a20b'), 'Fecha': datetime.datetime(2024, 7, 6, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 28348, 'Impresiones': 417987, 'Views': 16452, 'Costo': 1809}
# {'_id': ObjectId('66e855253d0b6a5338b0a20c'), 'Fecha': datetime.datetime(2024, 3, 31, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Este', 'Clicks': 35349, 'Impresiones': 235792, 'Views': 25617, 'Costo': 1784}
# {'_id': ObjectId('66e855253d0b6a5338b0a20d'), 'Fecha': datetime.datetime(2023, 12, 6, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 19166, 'Impresiones': 373099, 'Views': 23772, 'Costo': 1883}
# {'_id': ObjectId('66e855253d0b6a5338b0a20e'), 'Fecha': datetime.datetime(2024, 7, 1, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 36729, 'Impresiones': 112372, 'Views': 17648, 'Costo': 152}
# {'_id': ObjectId('66e855253d0b6a5338b0a20f'), 'Fecha': datetime.datetime(2023, 11, 28, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 28740, 'Impresiones': 376528, 'Views': 31400, 'Costo': 856}
# {'_id': ObjectId('66e855253d0b6a5338b0a210'), 'Fecha': datetime.datetime(2023, 12, 20, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Sur', 'Clicks': 45304, 'Impresiones': 107224, 'Views': 38925, 'Costo': 1423}
# {'_id': ObjectId('66e855253d0b6a5338b0a211'), 'Fecha': datetime.datetime(2024, 2, 6, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 23050, 'Impresiones': 234023, 'Views': 35952, 'Costo': 340}
# {'_id': ObjectId('66e855253d0b6a5338b0a212'), 'Fecha': datetime.datetime(2023, 8, 19, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Este', 'Clicks': 7307, 'Impresiones': 432162, 'Views': 12994, 'Costo': 1807}
# {'_id': ObjectId('66e855253d0b6a5338b0a213'), 'Fecha': datetime.datetime(2024, 6, 18, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Este', 'Clicks': 21779, 'Impresiones': 195145, 'Views': 17809, 'Costo': 1342}
# {'_id': ObjectId('66e855253d0b6a5338b0a214'), 'Fecha': datetime.datetime(2024, 4, 1, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Oeste', 'Clicks': 29805, 'Impresiones': 381302, 'Views': 19833, 'Costo': 1152}
# {'_id': ObjectId('66e855253d0b6a5338b0a215'), 'Fecha': datetime.datetime(2024, 5, 18, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Oeste', 'Clicks': 33457, 'Impresiones': 282612, 'Views': 24594, 'Costo': 1100}
# {'_id': ObjectId('66e855253d0b6a5338b0a216'), 'Fecha': datetime.datetime(2024, 7, 23, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Este', 'Clicks': 29819, 'Impresiones': 176797, 'Views': 14826, 'Costo': 778}
# {'_id': ObjectId('66e855253d0b6a5338b0a217'), 'Fecha': datetime.datetime(2024, 4, 7, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Oeste', 'Clicks': 48401, 'Impresiones': 281966, 'Views': 12680, 'Costo': 949}
# {'_id': ObjectId('66e855253d0b6a5338b0a218'), 'Fecha': datetime.datetime(2024, 5, 12, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 49996, 'Impresiones': 79199, 'Views': 38665, 'Costo': 1603}
# {'_id': ObjectId('66e855253d0b6a5338b0a219'), 'Fecha': datetime.datetime(2023, 10, 19, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Norte', 'Clicks': 32060, 'Impresiones': 143108, 'Views': 20286, 'Costo': 519}
# {'_id': ObjectId('66e855253d0b6a5338b0a21a'), 'Fecha': datetime.datetime(2024, 5, 23, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Norte', 'Clicks': 36518, 'Impresiones': 255825, 'Views': 12211, 'Costo': 472}
# {'_id': ObjectId('66e855253d0b6a5338b0a21b'), 'Fecha': datetime.datetime(2023, 8, 28, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Sur', 'Clicks': 37010, 'Impresiones': 237158, 'Views': 21989, 'Costo': 616}
# {'_id': ObjectId('66e855253d0b6a5338b0a21c'), 'Fecha': datetime.datetime(2024, 5, 23, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Norte', 'Clicks': 31545, 'Impresiones': 490317, 'Views': 24915, 'Costo': 1722}
# {'_id': ObjectId('66e855253d0b6a5338b0a21d'), 'Fecha': datetime.datetime(2023, 10, 25, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Sur', 'Clicks': 10911, 'Impresiones': 254348, 'Views': 13817, 'Costo': 617}
# {'_id': ObjectId('66e855253d0b6a5338b0a21e'), 'Fecha': datetime.datetime(2023, 8, 23, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 41422, 'Impresiones': 237795, 'Views': 43681, 'Costo': 1931}
# {'_id': ObjectId('66e855253d0b6a5338b0a21f'), 'Fecha': datetime.datetime(2024, 3, 6, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Sur', 'Clicks': 9804, 'Impresiones': 5064, 'Views': 38156, 'Costo': 1441}
# {'_id': ObjectId('66e855253d0b6a5338b0a220'), 'Fecha': datetime.datetime(2024, 5, 7, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Este', 'Clicks': 22068, 'Impresiones': 435276, 'Views': 34668, 'Costo': 577}
# {'_id': ObjectId('66e855253d0b6a5338b0a221'), 'Fecha': datetime.datetime(2023, 9, 15, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Oeste', 'Clicks': 22012, 'Impresiones': 151714, 'Views': 33379, 'Costo': 282}
# {'_id': ObjectId('66e855253d0b6a5338b0a222'), 'Fecha': datetime.datetime(2024, 6, 8, 6, 0), 'Nombre de la Campaña': 'AprendePythonFacil', 'Region': 'Este', 'Clicks': 39066, 'Impresiones': 412703, 'Views': 5830, 'Costo': 945}
# {'_id': ObjectId('66e855253d0b6a5338b0a223'), 'Fecha': datetime.datetime(2024, 3, 20, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Oeste', 'Clicks': 8492, 'Impresiones': 271501, 'Views': 23415, 'Costo': 611}
# {'_id': ObjectId('66e855253d0b6a5338b0a224'), 'Fecha': datetime.datetime(2024, 1, 10, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 29587, 'Impresiones': 99473, 'Views': 32469, 'Costo': 753}
# {'_id': ObjectId('66e855253d0b6a5338b0a225'), 'Fecha': datetime.datetime(2023, 10, 31, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Este', 'Clicks': 31943, 'Impresiones': 248545, 'Views': 21555, 'Costo': 882}
# {'_id': ObjectId('66e855253d0b6a5338b0a226'), 'Fecha': datetime.datetime(2024, 1, 29, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 34412, 'Impresiones': 290921, 'Views': 37562, 'Costo': 616}
# {'_id': ObjectId('66e855253d0b6a5338b0a227'), 'Fecha': datetime.datetime(2023, 11, 1, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Sur', 'Clicks': 8828, 'Impresiones': 367461, 'Views': 44047, 'Costo': 1306}
# {'_id': ObjectId('66e855253d0b6a5338b0a228'), 'Fecha': datetime.datetime(2024, 3, 15, 6, 0), 'Nombre de la Campaña': 'MasterEnPython', 'Region': 'Norte', 'Clicks': 24234, 'Impresiones': 354569, 'Views': 31836, 'Costo': 1937}
# {'_id': ObjectId('66e855253d0b6a5338b0a229'), 'Fecha': datetime.datetime(2023, 11, 26, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Norte', 'Clicks': 5016, 'Impresiones': 23477, 'Views': 47768, 'Costo': 456}
# {'_id': ObjectId('66e855253d0b6a5338b0a22a'), 'Fecha': datetime.datetime(2023, 12, 8, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Sur', 'Clicks': 20137, 'Impresiones': 356523, 'Views': 37410, 'Costo': 1197}
# {'_id': ObjectId('66e855253d0b6a5338b0a22b'), 'Fecha': datetime.datetime(2023, 11, 6, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 41105, 'Impresiones': 491614, 'Views': 6711, 'Costo': 1725}
# {'_id': ObjectId('66e855253d0b6a5338b0a22c'), 'Fecha': datetime.datetime(2023, 12, 4, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 15509, 'Impresiones': 349479, 'Views': 20643, 'Costo': 463}
# {'_id': ObjectId('66e855253d0b6a5338b0a22d'), 'Fecha': datetime.datetime(2024, 1, 28, 6, 0), 'Nombre de la Campaña': 'CursosDeProgramacion', 'Region': 'Sur', 'Clicks': 12424, 'Impresiones': 178723, 'Views': 17621, 'Costo': 1086}
# {'_id': ObjectId('66e855253d0b6a5338b0a22e'), 'Fecha': datetime.datetime(2024, 4, 1, 6, 0), 'Nombre de la Campaña': 'ProgramacionParaTodos', 'Region': 'Oeste', 'Clicks': 13475, 'Impresiones': 400527, 'Views': 49020, 'Costo': 107}
# {'_id': ObjectId('66e855253d0b6a5338b0a22f'), 'Fecha': datetime.datetime(2024, 3, 16, 6, 0), 'Nombre de la Campaña': 'ProgramacionDesdeCero', 'Region': 'Sur', 'Clicks': 40893, 'Impresiones': 388132, 'Views': 41581, 'Costo': 980}
# {'_id': ObjectId('66e855253d0b6a5338b0a230'), 'Fecha': datetime.datetime(2024, 4, 29, 6, 0), 'Nombre de la Campaña': 'CodigoFacilitoEnEspanol', 'Region': 'Oeste', 'Clicks': 28925, 'Impresiones': 384035, 'Views': 28182, 'Costo': 1601}
# {'_id': ObjectId('66e855253d0b6a5338b0a231'), 'Fecha': datetime.datetime(2024, 4, 23, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Oeste', 'Clicks': 16613, 'Impresiones': 165981, 'Views': 39955, 'Costo': 1007}
# {'_id': ObjectId('66e855253d0b6a5338b0a232'), 'Fecha': datetime.datetime(2023, 11, 15, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Norte', 'Clicks': 5641, 'Impresiones': 49815, 'Views': 15662, 'Costo': 1359}
# {'_id': ObjectId('66e855253d0b6a5338b0a233'), 'Fecha': datetime.datetime(2024, 6, 20, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Norte', 'Clicks': 28535, 'Impresiones': 352983, 'Views': 46780, 'Costo': 1635}
# {'_id': ObjectId('66e855253d0b6a5338b0a234'), 'Fecha': datetime.datetime(2024, 7, 6, 6, 0), 'Nombre de la Campaña': 'CursoDeJavaAvanzado', 'Region': 'Sur', 'Clicks': 29588, 'Impresiones': 40026, 'Views': 18668, 'Costo': 330}
# {'_id': ObjectId('66e855253d0b6a5338b0a235'), 'Fecha': datetime.datetime(2023, 12, 13, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Sur', 'Clicks': 24523, 'Impresiones': 238325, 'Views': 5276, 'Costo': 195}
# {'_id': ObjectId('66e855253d0b6a5338b0a236'), 'Fecha': datetime.datetime(2024, 1, 26, 6, 0), 'Nombre de la Campaña': 'AprendeCSharpFacil', 'Region': 'Este', 'Clicks': 22159, 'Impresiones': 437721, 'Views': 44179, 'Costo': 442}
# {'_id': ObjectId('66e855253d0b6a5338b0a237'), 'Fecha': datetime.datetime(2024, 1, 17, 6, 0), 'Nombre de la Campaña': 'AprendeJavaScriptYA', 'Region': 'Sur', 'Clicks': 47854, 'Impresiones': 359512, 'Views': 20689, 'Costo': 1674}
# {'_id': ObjectId('66e855253d0b6a5338b0a238'), 'Fecha': datetime.datetime(2023, 8, 21, 6, 0), 'Nombre de la Campaña': 'DesarrolloWebCompleto', 'Region': 'Este', 'Clicks': 14704, 'Impresiones': 301041, 'Views': 10286, 'Costo': 582}

# %%
def read_collection_df(collection):
    return pd.DataFrame(list(collection.find()))

read_collection_df(mycollection)
# Out:
#                           _id               Fecha     Nombre de la Campaña  \
# 0    66e855253d0b6a5338b09e51 2023-12-24 06:00:00     CursosDeProgramacion
# 1    66e855253d0b6a5338b09e52 2023-11-11 06:00:00       AprendeCSharpFacil
# 2    66e855253d0b6a5338b09e53 2024-05-24 06:00:00  CodigoFacilitoEnEspanol
# 3    66e855253d0b6a5338b09e54 2023-09-05 06:00:00       AprendePythonFacil
# 4    66e855253d0b6a5338b09e55 2024-06-19 06:00:00  CodigoFacilitoEnEspanol
# ..                        ...                 ...                      ...
# 995  66e855253d0b6a5338b0a234 2024-07-06 06:00:00      CursoDeJavaAvanzado
# 996  66e855253d0b6a5338b0a235 2023-12-13 06:00:00       AprendeCSharpFacil
# 997  66e855253d0b6a5338b0a236 2024-01-26 06:00:00       AprendeCSharpFacil
# 998  66e855253d0b6a5338b0a237 2024-01-17 06:00:00      AprendeJavaScriptYA
# 999  66e855253d0b6a5338b0a238 2023-08-21 06:00:00    DesarrolloWebCompleto
#
#     Region  Clicks  Impresiones  Views  Costo
# 0    Oeste   26148       133468  21979    606
# 1    Norte   34586       340290  49146    495
# 2    Norte   20337       343710  32831   1655
# 3      Sur   45332       279000  15840    991
# 4     Este   36817       462135  42041   1784
# ..     ...     ...          ...    ...    ...
# 995    Sur   29588        40026  18668    330
# 996    Sur   24523       238325   5276    195
# 997   Este   22159       437721  44179    442
# 998    Sur   47854       359512  20689   1674
# 999   Este   14704       301041  10286    582
#
# [1000 rows x 8 columns]

# %% [markdown]
# La línea de código `pd.DataFrame(list(collection.find()))` está realizando varias operaciones para convertir los documentos de una colección de MongoDB en un DataFrame de Pandas. Aquí está la explicación detallada de cómo funciona:
#
# 1. **`collection.find()`**:
#    - `collection` es un objeto que representa una colección en una base de datos MongoDB.
#    - El método `find()` se utiliza para realizar una consulta en la colección y recuperar todos los documentos. Si no se pasan parámetros a `find()`, se recuperan todos los documentos de la colección.
#    - El resultado de `find()` es un cursor, que es un iterador que permite recorrer los documentos recuperados uno por uno.
#
# 2. **`list(collection.find())`**:
#    - La función `list()` toma el cursor devuelto por `find()` y lo convierte en una lista de documentos. Cada documento en la lista es un diccionario de Python que representa un documento de MongoDB.
#    - Esta conversión es necesaria porque el cursor no puede ser directamente pasado a `pd.DataFrame()`. La lista resultante contiene todos los documentos de la colección en forma de diccionarios.
#
# 3. **`pd.DataFrame(list(collection.find()))`**:
#    - `pd.DataFrame()` es una función de la biblioteca Pandas que se utiliza para crear un DataFrame.
#    - Al pasar la lista de diccionarios a `pd.DataFrame()`, Pandas convierte cada diccionario en una fila del DataFrame. Las claves de los diccionarios se convierten en los nombres de las columnas del DataFrame.
#    - El resultado es un DataFrame de Pandas que contiene todos los documentos de la colección de MongoDB, con las columnas correspondientes a las claves de los diccionarios.
#
# En resumen, esta línea de código recupera todos los documentos de una colección de MongoDB, los convierte en una lista de diccionarios y luego crea un DataFrame de Pandas a partir de esa lista. Esto permite trabajar con los datos de MongoDB utilizando las poderosas herramientas de análisis y manipulación de datos que ofrece Pandas.

# %% [markdown]
# #### Ejecución de consultas para extraer datos específicos en MongoDB

# %%
def read_collection_df(collection, query={}):
    return pd.DataFrame(list(collection.find(query)))

query = {'Region': 'Norte'}
read_collection_df(mycollection, query)
# Out:
#                           _id               Fecha     Nombre de la Campaña  \
# 0    66e855253d0b6a5338b09e52 2023-11-11 06:00:00       AprendeCSharpFacil
# 1    66e855253d0b6a5338b09e53 2024-05-24 06:00:00  CodigoFacilitoEnEspanol
# 2    66e855253d0b6a5338b09e56 2023-08-22 06:00:00      AprendeJavaScriptYA
# 3    66e855253d0b6a5338b09e57 2024-04-10 06:00:00      AprendeJavaScriptYA
# 4    66e855253d0b6a5338b09e5c 2024-02-15 06:00:00      CursoDeJavaAvanzado
# ..                        ...                 ...                      ...
# 235  66e855253d0b6a5338b0a228 2024-03-15 06:00:00           MasterEnPython
# 236  66e855253d0b6a5338b0a229 2023-11-26 06:00:00      CursoDeJavaAvanzado
# 237  66e855253d0b6a5338b0a22c 2023-12-04 06:00:00    DesarrolloWebCompleto
# 238  66e855253d0b6a5338b0a232 2023-11-15 06:00:00    DesarrolloWebCompleto
# 239  66e855253d0b6a5338b0a233 2024-06-20 06:00:00       AprendeCSharpFacil
#
#     Region  Clicks  Impresiones  Views  Costo
# 0    Norte   34586       340290  49146    495
# 1    Norte   20337       343710  32831   1655
# 2    Norte   39359       440556   5551    205
# 3    Norte   24900       338969   8259    134
# 4    Norte   21897       400482  13804   1121
# ..     ...     ...          ...    ...    ...
# 235  Norte   24234       354569  31836   1937
# 236  Norte    5016        23477  47768    456
# 237  Norte   15509       349479  20643    463
# 238  Norte    5641        49815  15662   1359
# 239  Norte   28535       352983  46780   1635
#
# [240 rows x 8 columns]
