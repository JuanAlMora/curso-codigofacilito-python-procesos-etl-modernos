# %% [markdown]
# # Extraccion de datos desde archivos
#
# - CSV
# - JSON
# - Excel

# %%
import pandas as pd
import polars as pl
import os

path_data = os.path.join(os.getcwd(), 'data')

# %%
path_data
# Out:
# 'c:\\Users\\flavi\\Teaching\\Curso_Codigo-Facilito_Procesos-ETL-Modernos-Python\\Extraccion\\data'

# %% [markdown]
# ## CSV

# %%
pd.read_csv(
    filepath_or_buffer=os.path.join(path_data, 'dataset.csv'),
    )
# Out:
#           Fecha     Nombre de la Campaña Region  Clicks  Impresiones  Views  \
# 0    12/24/2023     CursosDeProgramacion  Oeste   26148       133468  21979
# 1    11/11/2023       AprendeCSharpFacil  Norte   34586       340290  49146
# 2     5/24/2024  CodigoFacilitoEnEspanol  Norte   20337       343710  32831
# 3      9/5/2023       AprendePythonFacil    Sur   45332       279000  15840
# 4     6/19/2024  CodigoFacilitoEnEspanol   Este   36817       462135  42041
# ..          ...                      ...    ...     ...          ...    ...
# 995    7/6/2024      CursoDeJavaAvanzado    Sur   29588        40026  18668
# 996  12/13/2023       AprendeCSharpFacil    Sur   24523       238325   5276
# 997   1/26/2024       AprendeCSharpFacil   Este   22159       437721  44179
# 998   1/17/2024      AprendeJavaScriptYA    Sur   47854       359512  20689
# 999   8/21/2023    DesarrolloWebCompleto   Este   14704       301041  10286
#
#      Costo
# 0      606
# 1      495
# 2     1655
# ...
